# %%
import numpy as np 
import pandas as pd

# %%
df_train = pd.read_csv('../data/cleaned/X_test_processed.csv')
df_test = pd.read_csv('../data/cleaned/X_test_processed.csv')

# %%
df_train.dropna(inplace=True)
df_train.isna().sum()
# Out:
# age                                   0
# alcohol_consumption_per_week          0
# physical_activity_minutes_per_week    0
# diet_score                            0
# sleep_hours_per_day                   0
#                                      ..
# cat_bin__triglycerides_bin_High       0
# cat_bin__triglycerides_bin_Normal     0
# remainder__family_history_diabetes    0
# remainder__hypertension_history       0
# remainder__cardiovascular_history     0
# Length: 119, dtype: int64

# %%
print("Train shape:", df_train.shape)
print("Test shape:", df_test.shape)
# Out:
# Train shape: (300000, 119)
# Test shape: (300000, 119)
